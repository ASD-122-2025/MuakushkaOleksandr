# %% [markdown]
# # Індивідуальне завдання
#
# **Номер студента в списку:** `12`
# **Задачі для розв’язання:** `12`, `12 + 5 - 15 = 2` (з циклічним переходом, якщо потрібно)
#
# ---
#
# ## Завдання 1
# ### Дано:
# - f(n) = 4n³ − 12n + 9
# - g(n) = n³
#
# ### Потрібно довести:
# **𝑓(𝑛) = Ω(𝑔(𝑛))**
#
# ---
#
# ### Розв’язання:
#
# Метод меж:
#
# > limₙ→∞ [f(n)/g(n)]
# > = limₙ→∞ [(4n³ − 12n + 9) / n³]
# > = limₙ→∞ [4 − 12/n² + 9/n³]
# > = 4
#
# Оскільки межа > 0 (сталий додатній коефіцієнт), то:
#
# > **f(n) = Ω(g(n))**
#
#  **Висновок:**
# Асимптотично 𝑓(𝑛) не зростає повільніше за 𝑔(𝑛), отже:
# **f(n) = Ω(n³)**
#
#
# ---
#
# ## Завдання 2
# ### Дано: f(n) = n³ + 2n² − 5n + 8
# -      g(n) = n⁴
# ### Потрібно довести:
# - f(n) = O(g(n)), використовуючи метод меж
#
# ### Розв’язання:
#  Обчислюємо межу:
# > lim[n→∞] (f(n)/g(n)) = lim[n→∞] [(n³ + 2n² − 5n + 8) / n⁴]
# >                      = lim[n→∞] [1/n + 2/n² − 5/n³ + 8/n⁴]
# >                      = 0
#
# # Висновок: f(n) = O(n⁴)
# ---
#
# # Контрольні питання
#
# ---
#
# ### **1. Що таке асимптотична складність алгоритму?**
#
# Асимптотична складність — це оцінка ефективності алгоритму при великих обсягах даних `n`,
# що описує його зростання часу або пам’яті без урахування констант.
#
# ---
#
# ### **2. Які інші нотації, крім O-нотації, використовуються для вираження асимптотичної складності?**
#
# - **Ω (омега)** — нижня межа складності
# - **Θ (тета)** — точна межа (і верхня, і нижня)
# - **o (маленьке о)** — "строга" верхня межа
# - **ω (маленька омега)** — "строга" нижня межа
#
# ---
#
# ### **3. Як визначити асимптотичну складність алгоритму за допомогою символів Θ і Ω?**
#
# - **Θ(g(n))** — f(n) зростає з тією ж швидкістю, що і g(n)
# - **Ω(g(n))** — f(n) зростає не повільніше, ніж g(n) (існує сталий множник і межа)
#
# Метод меж:
# - **Θ**: межа = сталий додатній коефіцієнт
# - **Ω**: межа ≥ сталого додатнього
# - **o**: межа → 0
# - **ω**: межа → ∞
#
# ---
#
# ### **4. Яка різниця між O-нотацією, Θ-нотацією і Ω-нотацією?**
#
# | Нотація | Описує                 | Визначає                       |
# |---------|------------------------|--------------------------------|
# | O       | Верхню межу            | Максимальний ріст              |
# | Ω       | Нижню межу             | Мінімальний ріст               |
# | Θ       | Точну межу             | Точний порядок зростання       |
#
# ---
#
# ### **5. Які основні властивості інших нотацій, таких як o (маленька о), ω (маленька омега) та o⁺ (з верхнім індексом)?**
#
# - **o(g(n))** — f(n) зростає _строго_ повільніше, ніж g(n):
#   > limₙ→∞ [f(n)/g(n)] = 0
# - **ω(g(n))** — f(n) зростає _строго_ швидше, ніж g(n):
#   > limₙ→∞ [f(n)/g(n)] = ∞
# - **o⁺** — варіант для ще більш точного аналізу, використовується рідко.
#
# ---
